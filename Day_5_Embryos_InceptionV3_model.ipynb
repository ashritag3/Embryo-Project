# %% [markdown]
# The LetoHealth app aids healthcare professionals specializing in infertility aid patients undergoing the IVF process to select the best embryo for lab transfer.

# %% [markdown]
# Loading Required Libraries

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data Reading 

import os
from glob import glob
from PIL import Image

# Data Processing 

import numpy as np
import pandas as pd
import cv2
import random
import albumentations as A

# Data Analysis

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# Data Modeling & Model Evaluation

from sklearn.model_selection import train_test_split
from keras.preprocessing import image
from tensorflow.keras import layers, models
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score, accuracy_score, precision_score, f1_score


# Grad-CAM

import keras
import matplotlib.cm as cm

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image

# %% [markdown]
# # Reading the data

# %%
levels = ['1', '2', '3', '4', '5']
path = "embryo-dataset/ed4/alldata"
data_dir = os.path.join(path)

data = []
for id, level in enumerate(levels):
    for file in os.listdir(os.path.join(data_dir, level)):
        data.append(['{}/{}'.format(level, file), level])

data = pd.DataFrame(data, columns = ['image_file', 'embryo_dataset'])

data['path'] = path + '/' + data['image_file']
data['embryo_dataset'] = data['embryo_dataset'].map({'1': 'Degenerate','2': 'Morula','3':'Early Blastocyst', '4': 'Full Blastocyst','5': 'Hatched Blastocyst'})

samples = 2440

data.head(2400)
# Out:
#      image_file      embryo_dataset                                  path
# 0       1/0.png          Degenerate    embryo-dataset/ed4/alldata/1/0.png
# 1       1/1.png          Degenerate    embryo-dataset/ed4/alldata/1/1.png
# 2      1/10.png          Degenerate   embryo-dataset/ed4/alldata/1/10.png
# 3     1/100.png          Degenerate  embryo-dataset/ed4/alldata/1/100.png
# 4     1/101.png          Degenerate  embryo-dataset/ed4/alldata/1/101.png
# ...         ...                 ...                                   ...
# 2395  5/703.png  Hatched Blastocyst  embryo-dataset/ed4/alldata/5/703.png
# 2396  5/704.png  Hatched Blastocyst  embryo-dataset/ed4/alldata/5/704.png
# 2397  5/705.png  Hatched Blastocyst  embryo-dataset/ed4/alldata/5/705.png
# 2398  5/706.png  Hatched Blastocyst  embryo-dataset/ed4/alldata/5/706.png
# 2399  5/707.png  Hatched Blastocyst  embryo-dataset/ed4/alldata/5/707.png
#
# [2400 rows x 3 columns]

# %%
print('Number of Duplicated Samples: %d'%(data.duplicated().sum()))
print('Number of Total Samples: %d'%(data.isnull().value_counts()))
# Out:
# Number of Duplicated Samples: 0
# Number of Total Samples: 2440

# %% [markdown]
# # Data Modeling

# %% [markdown]
# Pre-Process Data

# %%
IMAGE_SIZE = 128
all_data = []

# Storing images and their labels into a list for further Train Test split

for i in range(len(data)):
    image = cv2.imread(data['path'][i])
    image = cv2.resize(image, (IMAGE_SIZE, IMAGE_SIZE)) / 255.0
    if data['embryo_dataset'][i] == 'Degenerate':
        label = 1
    elif data['embryo_dataset'][i] == 'Morula':
        label = 2
    elif data['embryo_dataset'][i] == 'Early Blastocyst':
        label = 3
    elif data['embryo_dataset'][i] == 'Full Blastocyst':
        label = 4
    elif data['embryo_dataset'][i] == 'Hatched Blastocyst':
        label = 5
    all_data.append([image, label])

# %%
data['embryo_dataset'][0]
# Out:
# 'Degenerate'

# %%
label
# Out:
# 5

# %% [markdown]
# Shuffle Data before Train-Test-Split

# %%
random.shuffle(all_data)

# %% [markdown]
# Train Test Split

# %%
x = []
y = []

for image, label in all_data:
    x.append(image)
    y.append(label)

# Converting to Numpy Array    
x = np.array(x)
y = np.array(y)

val_split = 0.1
test_split = 0.25
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = test_split, stratify=y, random_state = 42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = val_split, random_state = 42)

x = np.concatenate((x_train, x_val))
y = np.concatenate((y_train, y_val))

# %%
print(x_train.shape, x_test.shape, x_val.shape, y_train.shape, y_test.shape, y_val.shape)
# Out:
# (1647, 128, 128, 3) (610, 128, 128, 3) (183, 128, 128, 3) (1647,) (610,) (183,)

# %%
y
# Out:
# array([3, 2, 1, ..., 5, 1, 2])

# %%
y_train[4]
# Out:
# 4

# %% [markdown]
# # Encode the labels using LabelBinarizer

# %%
from sklearn.preprocessing import LabelBinarizer

lb=LabelBinarizer()

y_train=lb.fit_transform(y_train)
y_val=lb.fit_transform(y_val)
y_test=lb.fit_transform(y_test)

# %%
y_train[1]
# Out:
# array([0, 1, 0, 0, 0])

# %%
y_val[1]
# Out:
# array([0, 0, 0, 0, 1])

# %%
y_test[4]
# Out:
# array([0, 0, 0, 0, 1])

# %%
#training split
len(x_train)
# Out:
# 1647

# %%
#testing split
len(x_test)
# Out:
# 610

# %%
# valuation split
len(x_val)
# Out:
# 183

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# # Instantiate the InceptionV3 model

# %%
IMAGE_SIZE = 128

#Load Model
inception = tf.keras.applications.InceptionV3(weights='imagenet',include_top=False,input_shape=(IMAGE_SIZE,IMAGE_SIZE,3))


for layer in inception.layers[:-10]:
    layer.trainable = False # Freeze weights of all layers till except the last 10
    
last_layer = inception.get_layer('mixed7')

print('last layer output shape: ', last_layer.output_shape)

layer_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
from shutil import copyfile
from tensorflow.keras.layers import Conv2D,Add,MaxPooling2D, Dense, BatchNormalization,Input,Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
x = Flatten()(layer_output)
x = BatchNormalization()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(5, activation='softmax')(x)
model = Model(inception.input, outputs)

# %% [markdown]
# # Model summary

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 63, 63, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 63, 63, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 63, 63, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 61, 61, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 61, 61, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 61, 61, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 61, 61, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 61, 61, 64)  192         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 61, 61, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 30, 30, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 30, 30, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 30, 30, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 30, 30, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 28, 28, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 13, 13, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 13, 13, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 13, 13, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 13, 13, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 13, 13, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 13, 13, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 13, 13, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 13, 13, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 13, 13, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 13, 13, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 13, 13, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 13, 13, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 13, 13, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 13, 13, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 13, 13, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 13, 13, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#  batch_normalization_10 (BatchN  (None, 13, 13, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 13, 13, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 13, 13, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 13, 13, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 13, 13, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 13, 13, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 13, 13, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 13, 13, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 13, 13, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 13, 13, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 13, 13, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 13, 13, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 13, 13, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 13, 13, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 13, 13, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 13, 13, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 13, 13, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 13, 13, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 13, 13, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 13, 13, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 13, 13, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 13, 13, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_22[0][0]']
#  conv2d_20 (Conv2D)             (None, 13, 13, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 13, 13, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 13, 13, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 13, 13, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 13, 13, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 13, 13, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 13, 13, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 13, 13, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 13, 13, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 13, 13, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 13, 13, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 13, 13, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 13, 13, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 13, 13, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 13, 13, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 13, 13, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 13, 13, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 13, 13, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 13, 13, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 13, 13, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 6, 6, 96)     82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 6, 6, 384)   1152        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 6, 6, 96)    288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 6, 6, 384)    0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 6, 6, 96)     0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 6, 6, 768)    0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 6, 6, 128)   384         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 6, 6, 128)    114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 6, 6, 128)   384         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 6, 6, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 6, 6, 128)    114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 6, 6, 128)   384         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 6, 6, 128)   384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 6, 6, 128)    114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 6, 6, 128)    114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 6, 6, 128)   384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 6, 6, 128)   384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 6, 6, 128)    0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 6, 6, 768)   0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 6, 6, 192)    172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 6, 6, 192)    172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 6, 6, 192)    147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 6, 6, 192)   576         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 6, 6, 192)   576         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 6, 6, 192)   576         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 6, 6, 192)   576         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 6, 6, 768)    0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 6, 6, 160)   480         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 6, 6, 160)   480         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 6, 6, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 6, 6, 160)   480         ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 6, 6, 160)   480         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 6, 6, 160)   480         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 6, 6, 160)   480         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 6, 6, 768)   0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 6, 6, 192)    215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 6, 6, 192)    215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 6, 6, 192)    147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 6, 6, 192)   576         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 6, 6, 192)   576         ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 6, 6, 192)   576         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 6, 6, 192)   576         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 6, 6, 768)    0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 6, 6, 160)   480         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_54[0][0]']
#  batch_normalization_55 (BatchN  (None, 6, 6, 160)   480         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 6, 6, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 6, 6, 160)   480         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 6, 6, 160)   480         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 6, 6, 160)    179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 6, 6, 160)   480         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 6, 6, 160)   480         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 6, 6, 160)    0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 6, 6, 768)   0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 6, 6, 192)    215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 6, 6, 192)    215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 6, 6, 192)    147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 6, 6, 192)   576         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 6, 6, 192)   576         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 6, 6, 192)   576         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 6, 6, 192)   576         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 6, 6, 768)    0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 6, 6, 192)   576         ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 6, 6, 192)   576         ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_65[0][0]']
#  conv2d_61 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_65[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 6, 6, 192)   576         ['conv2d_61[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 6, 6, 192)   576         ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_61[0][0]']
#
#  activation_66 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_66[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_61[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_66[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 6, 6, 192)   576         ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 6, 6, 192)   576         ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_62[0][0]']
#
#  activation_67 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_67[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 6, 6, 768)   0           ['mixed6[0][0]']
#  oling2D)
#
#  conv2d_60 (Conv2D)             (None, 6, 6, 192)    147456      ['mixed6[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_62[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 6, 6, 192)    258048      ['activation_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 6, 6, 192)    147456      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 6, 6, 192)   576         ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 6, 6, 192)   576         ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 6, 6, 192)   576         ['conv2d_68[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 6, 6, 192)   576         ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_60[0][0]']
#
#  activation_63 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_63[0][0]']
#
#  activation_68 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_68[0][0]']
#
#  activation_69 (Activation)     (None, 6, 6, 192)    0           ['batch_normalization_69[0][0]']
#
#  mixed7 (Concatenate)           (None, 6, 6, 768)    0           ['activation_60[0][0]',
#                                                                   'activation_63[0][0]',
#                                                                   'activation_68[0][0]',
#                                                                   'activation_69[0][0]']
#
#  flatten (Flatten)              (None, 27648)        0           ['mixed7[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 27648)       110592      ['flatten[0][0]']
#  ormalization)
#
#  dense (Dense)                  (None, 1024)         28312576    ['batch_normalization_94[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 5)            5125        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 37,403,557
# Trainable params: 28,372,997
# Non-trainable params: 9,030,560
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Nadam
opt = Nadam(learning_rate=1e-4, decay=1e-4)
model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])

# %% [markdown]
# # Data Augmentation

# %%
# Use the Image Data Generator to import the images from the dataset
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   featurewise_center = False,
                                    samplewise_center = False,
                                    featurewise_std_normalization = False,
                                    samplewise_std_normalization = False,
                                    zca_whitening = False,
                                    rotation_range = 0,
                                    #zoom_range = 0.1,
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1,
                                    horizontal_flip = True,
                                    #vertical_flip = True,
                                   validation_split=0.5
                                  )

test_datagen = ImageDataGenerator(rescale = 1./255, validation_split=0.5)

# %%
# Make sure you provide the same target size as initialied for the image size
BATCH_SIZE = 32
IMAGE_SIZE = 128
training_set = train_datagen.flow_from_directory('embryo-dataset/ed4/alldata',
                                                 target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                                 batch_size = BATCH_SIZE,
                                                 subset='training',
                                                 shuffle=True,
                                                 seed=66,
                                                 class_mode = 'categorical')
# Out:
# Found 1222 images belonging to 5 classes.

# %%
test_set = test_datagen.flow_from_directory('embryo-dataset/ed4/alldata',
                                            target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                            batch_size = BATCH_SIZE,
                                            subset='validation',
                                            shuffle=False,
                                            seed=66,
                                            class_mode = 'categorical')
# Out:
# Found 1218 images belonging to 5 classes.

# %%
history = model.fit(
  training_set,
  validation_data=test_set,
  epochs=150,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/150
# 39/39 [==============================] - 138s 3s/step - loss: 1.7688 - accuracy: 0.3813 - val_loss: 1.4367 - val_accuracy: 0.3415
# Epoch 2/150
# 39/39 [==============================] - 85s 2s/step - loss: 1.5113 - accuracy: 0.4869 - val_loss: 1.2930 - val_accuracy: 0.4409
# Epoch 3/150
# 39/39 [==============================] - 85s 2s/step - loss: 1.4164 - accuracy: 0.5466 - val_loss: 1.2251 - val_accuracy: 0.4762
# Epoch 4/150
# 39/39 [==============================] - 88s 2s/step - loss: 1.4408 - accuracy: 0.5614 - val_loss: 1.2036 - val_accuracy: 0.4745
# Epoch 5/150
# 39/39 [==============================] - 87s 2s/step - loss: 1.3530 - accuracy: 0.5712 - val_loss: 1.2547 - val_accuracy: 0.4918
# Epoch 6/150
# 39/39 [==============================] - 87s 2s/step - loss: 1.2029 - accuracy: 0.6121 - val_loss: 1.3770 - val_accuracy: 0.4581
# Epoch 7/150
# 39/39 [==============================] - 85s 2s/step - loss: 1.2449 - accuracy: 0.6105 - val_loss: 1.3318 - val_accuracy: 0.4778
# Epoch 8/150
# 39/39 [==============================] - 85s 2s/step - loss: 1.1736 - accuracy: 0.6211 - val_loss: 1.3309 - val_accuracy: 0.5016
# Epoch 9/150
# 39/39 [==============================] - 102s 3s/step - loss: 1.1898 - accuracy: 0.6285 - val_loss: 1.3358 - val_accuracy: 0.5164
# Epoch 10/150
# 39/39 [==============================] - 121s 3s/step - loss: 1.1020 - accuracy: 0.6538 - val_loss: 1.3886 - val_accuracy: 0.5115
# Epoch 11/150
# 39/39 [==============================] - 106s 3s/step - loss: 1.1125 - accuracy: 0.6481 - val_loss: 1.4634 - val_accuracy: 0.5230
# Epoch 12/150
# 39/39 [==============================] - 96s 2s/step - loss: 1.0403 - accuracy: 0.6498 - val_loss: 1.5112 - val_accuracy: 0.4992
# Epoch 13/150
# 39/39 [==============================] - 89s 2s/step - loss: 1.0041 - accuracy: 0.6759 - val_loss: 1.5406 - val_accuracy: 0.5140
# Epoch 14/150
# 39/39 [==============================] - 82s 2s/step - loss: 0.9471 - accuracy: 0.6866 - val_loss: 1.5539 - val_accuracy: 0.5222
# Epoch 15/150
# 39/39 [==============================] - 81s 2s/step - loss: 0.9257 - accuracy: 0.6858 - val_loss: 1.5767 - val_accuracy: 0.5205
# Epoch 16/150
# 39/39 [==============================] - 82s 2s/step - loss: 0.8582 - accuracy: 0.7029 - val_loss: 1.5092 - val_accuracy: 0.5131
# Epoch 17/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.8399 - accuracy: 0.7119 - val_loss: 1.5048 - val_accuracy: 0.5205
# Epoch 18/150
# 39/39 [==============================] - 89s 2s/step - loss: 0.7797 - accuracy: 0.7316 - val_loss: 1.5293 - val_accuracy: 0.5115
# Epoch 19/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.7663 - accuracy: 0.7218 - val_loss: 1.5340 - val_accuracy: 0.5033
# Epoch 20/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.6917 - accuracy: 0.7512 - val_loss: 1.5261 - val_accuracy: 0.5181
# Epoch 21/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.7412 - accuracy: 0.7308 - val_loss: 1.5279 - val_accuracy: 0.4959
# Epoch 22/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.6716 - accuracy: 0.7709 - val_loss: 1.5086 - val_accuracy: 0.5016
# Epoch 23/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.6641 - accuracy: 0.7537 - val_loss: 1.5595 - val_accuracy: 0.5057
# Epoch 24/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.6313 - accuracy: 0.7643 - val_loss: 1.5841 - val_accuracy: 0.5016
# Epoch 25/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.6289 - accuracy: 0.7700 - val_loss: 1.5256 - val_accuracy: 0.4992
# Epoch 26/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.6395 - accuracy: 0.7848 - val_loss: 1.5270 - val_accuracy: 0.5131
# Epoch 27/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.6570 - accuracy: 0.7578 - val_loss: 1.5678 - val_accuracy: 0.5066
# Epoch 28/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.5898 - accuracy: 0.7856 - val_loss: 1.5346 - val_accuracy: 0.5131
# Epoch 29/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.6026 - accuracy: 0.7717 - val_loss: 1.5954 - val_accuracy: 0.4836
# Epoch 30/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.5312 - accuracy: 0.8085 - val_loss: 1.5653 - val_accuracy: 0.5123
# Epoch 31/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.5589 - accuracy: 0.7995 - val_loss: 1.5789 - val_accuracy: 0.5222
# Epoch 32/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.5311 - accuracy: 0.8085 - val_loss: 1.5584 - val_accuracy: 0.5090
# Epoch 33/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.5460 - accuracy: 0.7995 - val_loss: 1.5370 - val_accuracy: 0.5082
# Epoch 34/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.5731 - accuracy: 0.7864 - val_loss: 1.5278 - val_accuracy: 0.5123
# Epoch 35/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.5299 - accuracy: 0.8020 - val_loss: 1.5193 - val_accuracy: 0.5181
# Epoch 36/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.5422 - accuracy: 0.8020 - val_loss: 1.6166 - val_accuracy: 0.5230
# Epoch 37/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.4663 - accuracy: 0.8142 - val_loss: 1.6317 - val_accuracy: 0.5033
# Epoch 38/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.5380 - accuracy: 0.8118 - val_loss: 1.5979 - val_accuracy: 0.5197
# Epoch 39/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.4959 - accuracy: 0.8208 - val_loss: 1.5978 - val_accuracy: 0.5337
# Epoch 40/150
# 39/39 [==============================] - 83s 2s/step - loss: 0.4789 - accuracy: 0.8191 - val_loss: 1.6311 - val_accuracy: 0.5164
# Epoch 41/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.4926 - accuracy: 0.8175 - val_loss: 1.6944 - val_accuracy: 0.5099
# Epoch 42/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.4715 - accuracy: 0.8339 - val_loss: 1.6611 - val_accuracy: 0.5189
# Epoch 43/150
# 39/39 [==============================] - 115s 3s/step - loss: 0.4635 - accuracy: 0.8257 - val_loss: 1.6562 - val_accuracy: 0.5238
# Epoch 44/150
# 39/39 [==============================] - 115s 3s/step - loss: 0.4645 - accuracy: 0.8314 - val_loss: 1.6715 - val_accuracy: 0.5131
# Epoch 45/150
# 39/39 [==============================] - 108s 3s/step - loss: 0.4641 - accuracy: 0.8249 - val_loss: 1.6501 - val_accuracy: 0.5213
# Epoch 46/150
# 39/39 [==============================] - 112s 3s/step - loss: 0.4549 - accuracy: 0.8388 - val_loss: 1.6795 - val_accuracy: 0.5271
# Epoch 47/150
# 39/39 [==============================] - 100s 3s/step - loss: 0.4300 - accuracy: 0.8437 - val_loss: 1.7509 - val_accuracy: 0.5156
# Epoch 48/150
# 39/39 [==============================] - 98s 3s/step - loss: 0.4810 - accuracy: 0.8363 - val_loss: 1.7292 - val_accuracy: 0.5123
# Epoch 49/150
# 39/39 [==============================] - 90s 2s/step - loss: 0.4595 - accuracy: 0.8273 - val_loss: 1.7143 - val_accuracy: 0.5107
# Epoch 50/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.4391 - accuracy: 0.8290 - val_loss: 1.8255 - val_accuracy: 0.4984
# Epoch 51/150
# 39/39 [==============================] - 104s 3s/step - loss: 0.4398 - accuracy: 0.8453 - val_loss: 1.7362 - val_accuracy: 0.5123
# Epoch 52/150
# 39/39 [==============================] - 103s 3s/step - loss: 0.4206 - accuracy: 0.8412 - val_loss: 1.7228 - val_accuracy: 0.5131
# Epoch 53/150
# 39/39 [==============================] - 90s 2s/step - loss: 0.3910 - accuracy: 0.8560 - val_loss: 1.7469 - val_accuracy: 0.4918
# Epoch 54/150
# 39/39 [==============================] - 91s 2s/step - loss: 0.3546 - accuracy: 0.8748 - val_loss: 1.7259 - val_accuracy: 0.5057
# Epoch 55/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.3543 - accuracy: 0.8691 - val_loss: 1.7382 - val_accuracy: 0.5205
# Epoch 56/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.3605 - accuracy: 0.8682 - val_loss: 1.7372 - val_accuracy: 0.5148
# Epoch 57/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.3332 - accuracy: 0.8813 - val_loss: 1.7440 - val_accuracy: 0.5181
# Epoch 58/150
# 39/39 [==============================] - 82s 2s/step - loss: 0.3477 - accuracy: 0.8674 - val_loss: 1.7665 - val_accuracy: 0.5345
# Epoch 59/150
# 39/39 [==============================] - 82s 2s/step - loss: 0.3476 - accuracy: 0.8764 - val_loss: 1.8333 - val_accuracy: 0.5296
# Epoch 60/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.4121 - accuracy: 0.8519 - val_loss: 1.8435 - val_accuracy: 0.5238
# Epoch 61/150
# 39/39 [==============================] - 82s 2s/step - loss: 0.3742 - accuracy: 0.8666 - val_loss: 1.8151 - val_accuracy: 0.5386
# Epoch 62/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.3373 - accuracy: 0.8650 - val_loss: 1.7799 - val_accuracy: 0.5238
# Epoch 63/150
# 39/39 [==============================] - 97s 2s/step - loss: 0.3301 - accuracy: 0.8732 - val_loss: 1.8558 - val_accuracy: 0.5312
# Epoch 64/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.3666 - accuracy: 0.8691 - val_loss: 1.9082 - val_accuracy: 0.5181
# Epoch 65/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.3713 - accuracy: 0.8658 - val_loss: 1.9203 - val_accuracy: 0.5304
# Epoch 66/150
# 39/39 [==============================] - 93s 2s/step - loss: 0.3466 - accuracy: 0.8764 - val_loss: 1.9090 - val_accuracy: 0.5189
# Epoch 67/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.3480 - accuracy: 0.8740 - val_loss: 1.8487 - val_accuracy: 0.5181
# Epoch 68/150
# 39/39 [==============================] - 107s 3s/step - loss: 0.3210 - accuracy: 0.8903 - val_loss: 1.8211 - val_accuracy: 0.5304
# Epoch 69/150
# 39/39 [==============================] - 92s 2s/step - loss: 0.2832 - accuracy: 0.9018 - val_loss: 1.8583 - val_accuracy: 0.5213
# Epoch 70/150
# 39/39 [==============================] - 92s 2s/step - loss: 0.3720 - accuracy: 0.8642 - val_loss: 1.8715 - val_accuracy: 0.5205
# Epoch 71/150
# 39/39 [==============================] - 97s 3s/step - loss: 0.3248 - accuracy: 0.8887 - val_loss: 1.8680 - val_accuracy: 0.5246
# Epoch 72/150
# 39/39 [==============================] - 105s 3s/step - loss: 0.3236 - accuracy: 0.8732 - val_loss: 1.9373 - val_accuracy: 0.5411
# Epoch 73/150
# 39/39 [==============================] - 111s 3s/step - loss: 0.3206 - accuracy: 0.8715 - val_loss: 1.9962 - val_accuracy: 0.5222
# Epoch 74/150
# 39/39 [==============================] - 100s 3s/step - loss: 0.3668 - accuracy: 0.8838 - val_loss: 1.9537 - val_accuracy: 0.5287
# Epoch 75/150
# 39/39 [==============================] - 91s 2s/step - loss: 0.2914 - accuracy: 0.8985 - val_loss: 1.9082 - val_accuracy: 0.5222
# Epoch 76/150
# 39/39 [==============================] - 93s 2s/step - loss: 0.2793 - accuracy: 0.9051 - val_loss: 1.9297 - val_accuracy: 0.5402
# Epoch 77/150
# 39/39 [==============================] - 93s 2s/step - loss: 0.3476 - accuracy: 0.8813 - val_loss: 1.9258 - val_accuracy: 0.5189
# Epoch 78/150
# 39/39 [==============================] - 93s 2s/step - loss: 0.3161 - accuracy: 0.8830 - val_loss: 1.9665 - val_accuracy: 0.5000
# Epoch 79/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.3165 - accuracy: 0.8756 - val_loss: 1.9606 - val_accuracy: 0.5066
# Epoch 80/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.2699 - accuracy: 0.9124 - val_loss: 1.9671 - val_accuracy: 0.5172
# Epoch 81/150
# 39/39 [==============================] - 87s 2s/step - loss: 0.3168 - accuracy: 0.8961 - val_loss: 1.9246 - val_accuracy: 0.5279
# Epoch 82/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.3148 - accuracy: 0.8887 - val_loss: 1.9284 - val_accuracy: 0.5279
# Epoch 83/150
# 39/39 [==============================] - 89s 2s/step - loss: 0.3155 - accuracy: 0.8723 - val_loss: 1.8847 - val_accuracy: 0.5205
# Epoch 84/150
# 39/39 [==============================] - 105s 3s/step - loss: 0.2820 - accuracy: 0.8903 - val_loss: 1.9564 - val_accuracy: 0.5230
# Epoch 85/150
# 39/39 [==============================] - 124s 3s/step - loss: 0.2757 - accuracy: 0.8854 - val_loss: 1.9707 - val_accuracy: 0.5238
# Epoch 86/150
# 39/39 [==============================] - 113s 3s/step - loss: 0.2947 - accuracy: 0.8928 - val_loss: 2.0059 - val_accuracy: 0.5238
# Epoch 87/150
# 39/39 [==============================] - 102s 3s/step - loss: 0.3017 - accuracy: 0.8944 - val_loss: 2.0115 - val_accuracy: 0.5205
# Epoch 88/150
# 39/39 [==============================] - 99s 3s/step - loss: 0.2821 - accuracy: 0.8936 - val_loss: 1.9882 - val_accuracy: 0.5296
# Epoch 89/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.2907 - accuracy: 0.8961 - val_loss: 1.9790 - val_accuracy: 0.5337
# Epoch 90/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.3223 - accuracy: 0.8871 - val_loss: 2.0003 - val_accuracy: 0.5255
# Epoch 91/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.3067 - accuracy: 0.8895 - val_loss: 1.9576 - val_accuracy: 0.5238
# Epoch 92/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.2750 - accuracy: 0.9034 - val_loss: 2.0123 - val_accuracy: 0.5057
# Epoch 93/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.2383 - accuracy: 0.9100 - val_loss: 1.9970 - val_accuracy: 0.5123
# Epoch 94/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.3091 - accuracy: 0.8961 - val_loss: 2.1091 - val_accuracy: 0.4992
# Epoch 95/150
# 39/39 [==============================] - 86s 2s/step - loss: 0.3187 - accuracy: 0.8863 - val_loss: 1.9787 - val_accuracy: 0.5123
# Epoch 96/150
# 39/39 [==============================] - 89s 2s/step - loss: 0.2775 - accuracy: 0.9157 - val_loss: 2.0071 - val_accuracy: 0.5099
# Epoch 97/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.2393 - accuracy: 0.9092 - val_loss: 1.9921 - val_accuracy: 0.5213
# Epoch 98/150
# 39/39 [==============================] - 85s 2s/step - loss: 0.2700 - accuracy: 0.9018 - val_loss: 2.0593 - val_accuracy: 0.5131
# Epoch 99/150
# 39/39 [==============================] - 98s 3s/step - loss: 0.2557 - accuracy: 0.9141 - val_loss: 2.0490 - val_accuracy: 0.5345
# Epoch 100/150
# 39/39 [==============================] - 88s 2s/step - loss: 0.2728 - accuracy: 0.9051 - val_loss: 2.0930 - val_accuracy: 0.5246
# Epoch 101/150
# 39/39 [==============================] - 89s 2s/step - loss: 0.2210 - accuracy: 0.9173 - val_loss: 2.0643 - val_accuracy: 0.5074
# Epoch 102/150
# 39/39 [==============================] - 147s 4s/step - loss: 0.2775 - accuracy: 0.8977 - val_loss: 2.1219 - val_accuracy: 0.5131
# Epoch 103/150
# 39/39 [==============================] - 129s 3s/step - loss: 0.2428 - accuracy: 0.9141 - val_loss: 2.1145 - val_accuracy: 0.5033
# Epoch 104/150
# 39/39 [==============================] - 100s 3s/step - loss: 0.2564 - accuracy: 0.9108 - val_loss: 2.0828 - val_accuracy: 0.5107
# Epoch 105/150
# 39/39 [==============================] - 98s 3s/step - loss: 0.2458 - accuracy: 0.9133 - val_loss: 2.1315 - val_accuracy: 0.5164
# Epoch 106/150
# 39/39 [==============================] - 108s 3s/step - loss: 0.2557 - accuracy: 0.9092 - val_loss: 2.0875 - val_accuracy: 0.5386
# Epoch 107/150
# 39/39 [==============================] - 103s 3s/step - loss: 0.2274 - accuracy: 0.9116 - val_loss: 2.1433 - val_accuracy: 0.5008
# Epoch 108/150
# 39/39 [==============================] - 111s 3s/step - loss: 0.2565 - accuracy: 0.9067 - val_loss: 2.0739 - val_accuracy: 0.5213
# Epoch 109/150
# 39/39 [==============================] - 96s 2s/step - loss: 0.2357 - accuracy: 0.9116 - val_loss: 2.1671 - val_accuracy: 0.5115
# Epoch 110/150
# 39/39 [==============================] - 92s 2s/step - loss: 0.2506 - accuracy: 0.9092 - val_loss: 2.1204 - val_accuracy: 0.5164
# Epoch 111/150
# 39/39 [==============================] - 91s 2s/step - loss: 0.2576 - accuracy: 0.9133 - val_loss: 2.0633 - val_accuracy: 0.5279
# Epoch 112/150
# 39/39 [==============================] - 98s 3s/step - loss: 0.2371 - accuracy: 0.9165 - val_loss: 2.0219 - val_accuracy: 0.5369
# Epoch 113/150
# 39/39 [==============================] - 102s 3s/step - loss: 0.2134 - accuracy: 0.9157 - val_loss: 1.9774 - val_accuracy: 0.5279
# Epoch 114/150
# 39/39 [==============================] - 97s 2s/step - loss: 0.2379 - accuracy: 0.9157 - val_loss: 2.0450 - val_accuracy: 0.5255
# Epoch 115/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.2580 - accuracy: 0.9075 - val_loss: 2.0950 - val_accuracy: 0.5238
# Epoch 116/150
# 39/39 [==============================] - 97s 2s/step - loss: 0.2444 - accuracy: 0.9198 - val_loss: 2.0923 - val_accuracy: 0.5148
# Epoch 117/150
# 39/39 [==============================] - 94s 2s/step - loss: 0.2178 - accuracy: 0.9165 - val_loss: 2.1878 - val_accuracy: 0.5213
# Epoch 118/150
# 39/39 [==============================] - 94s 2s/step - loss: 0.2308 - accuracy: 0.9067 - val_loss: 2.1823 - val_accuracy: 0.5230
# Epoch 119/150
# 39/39 [==============================] - 95s 2s/step - loss: 0.2221 - accuracy: 0.9149 - val_loss: 2.1932 - val_accuracy: 0.5213
# Epoch 120/150
# 39/39 [==============================] - 96s 2s/step - loss: 0.1901 - accuracy: 0.9272 - val_loss: 2.1430 - val_accuracy: 0.5189
# Epoch 121/150
# 39/39 [==============================] - 93s 2s/step - loss: 0.2291 - accuracy: 0.9239 - val_loss: 2.1114 - val_accuracy: 0.5172
# Epoch 122/150
# 39/39 [==============================] - 101s 3s/step - loss: 0.2107 - accuracy: 0.9296 - val_loss: 2.1365 - val_accuracy: 0.5107
# Epoch 123/150
# 39/39 [==============================] - 96s 2s/step - loss: 0.2093 - accuracy: 0.9255 - val_loss: 2.1255 - val_accuracy: 0.5213
# Epoch 124/150
# 39/39 [==============================] - 100s 3s/step - loss: 0.2654 - accuracy: 0.9206 - val_loss: 2.1532 - val_accuracy: 0.5156
# Epoch 125/150
# 39/39 [==============================] - 98s 2s/step - loss: 0.2005 - accuracy: 0.9304 - val_loss: 2.1452 - val_accuracy: 0.5148
# Epoch 126/150
# 39/39 [==============================] - 84s 2s/step - loss: 0.2028 - accuracy: 0.9321 - val_loss: 2.0982 - val_accuracy: 0.5222
# Epoch 127/150
# 39/39 [==============================] - 52s 1s/step - loss: 0.2212 - accuracy: 0.9206 - val_loss: 2.2318 - val_accuracy: 0.5213
# Epoch 128/150
# 39/39 [==============================] - 53s 1s/step - loss: 0.2038 - accuracy: 0.9280 - val_loss: 2.2257 - val_accuracy: 0.5222
# Epoch 129/150
# 39/39 [==============================] - 56s 1s/step - loss: 0.2452 - accuracy: 0.9190 - val_loss: 2.2172 - val_accuracy: 0.5345
# Epoch 130/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.1830 - accuracy: 0.9337 - val_loss: 2.2497 - val_accuracy: 0.5189
# Epoch 131/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2058 - accuracy: 0.9239 - val_loss: 2.2101 - val_accuracy: 0.5386
# Epoch 132/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.1971 - accuracy: 0.9362 - val_loss: 2.2380 - val_accuracy: 0.5222
# Epoch 133/150
# 39/39 [==============================] - 51s 1s/step - loss: 0.1860 - accuracy: 0.9435 - val_loss: 2.2618 - val_accuracy: 0.5378
# Epoch 134/150
# 39/39 [==============================] - 52s 1s/step - loss: 0.1977 - accuracy: 0.9362 - val_loss: 2.2902 - val_accuracy: 0.5238
# Epoch 135/150
# 39/39 [==============================] - 59s 2s/step - loss: 0.2069 - accuracy: 0.9264 - val_loss: 2.2909 - val_accuracy: 0.5238
# Epoch 136/150
# 39/39 [==============================] - 66s 2s/step - loss: 0.2291 - accuracy: 0.9280 - val_loss: 2.2267 - val_accuracy: 0.5255
# Epoch 137/150
# 39/39 [==============================] - 62s 2s/step - loss: 0.1842 - accuracy: 0.9313 - val_loss: 2.2720 - val_accuracy: 0.5320
# Epoch 138/150
# 39/39 [==============================] - 62s 2s/step - loss: 0.1974 - accuracy: 0.9362 - val_loss: 2.2803 - val_accuracy: 0.5312
# Epoch 139/150
# 39/39 [==============================] - 54s 1s/step - loss: 0.1791 - accuracy: 0.9321 - val_loss: 2.3455 - val_accuracy: 0.5181
# Epoch 140/150
# 39/39 [==============================] - 51s 1s/step - loss: 0.2024 - accuracy: 0.9288 - val_loss: 2.2773 - val_accuracy: 0.5238
# Epoch 141/150
# 39/39 [==============================] - 51s 1s/step - loss: 0.2051 - accuracy: 0.9288 - val_loss: 2.2892 - val_accuracy: 0.5238
# Epoch 142/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2071 - accuracy: 0.9247 - val_loss: 2.3670 - val_accuracy: 0.5287
# Epoch 143/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2240 - accuracy: 0.9182 - val_loss: 2.2501 - val_accuracy: 0.5238
# Epoch 144/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2017 - accuracy: 0.9165 - val_loss: 2.2064 - val_accuracy: 0.5394
# Epoch 145/150
# 39/39 [==============================] - 51s 1s/step - loss: 0.2108 - accuracy: 0.9354 - val_loss: 2.2498 - val_accuracy: 0.5279
# Epoch 146/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.1842 - accuracy: 0.9394 - val_loss: 2.3005 - val_accuracy: 0.5197
# Epoch 147/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2231 - accuracy: 0.9116 - val_loss: 2.2760 - val_accuracy: 0.5164
# Epoch 148/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.2022 - accuracy: 0.9231 - val_loss: 2.2728 - val_accuracy: 0.5255
# Epoch 149/150
# 39/39 [==============================] - 49s 1s/step - loss: 0.1718 - accuracy: 0.9411 - val_loss: 2.2983 - val_accuracy: 0.5279
# Epoch 150/150
# 39/39 [==============================] - 50s 1s/step - loss: 0.1923 - accuracy: 0.9354 - val_loss: 2.3051 - val_accuracy: 0.5140

# %% [markdown]
# # Save Model

# %%
# h5 is a serialization format
#model.save('day5_embryo_inception_model.h5')

# %% [markdown]
# # Reports

# %%
history_df = pd.DataFrame(history.history)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history_df['loss'], label='training loss')
plt.plot(history_df['val_loss'], label='validation loss')
plt.title('InceptionV3-Day5-embryo-Loss Function')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history_df['accuracy'], label='training accuracy')
plt.plot(history_df['val_accuracy'], label='validation accuracy')
plt.title('Day 5 Embryos Xception Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
#plt.savefig('Results/Day-5 Embryos-InceptionV3-Model-Accuracy-Loss.png')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 history_df = pd.DataFrame(history.history)
#       3 plt.figure(figsize=(15,5))
#       4 plt.subplot(1,2,1)
#
# NameError: name 'history' is not defined

# %%
# Summarize History for Accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Day 5 Embryos Xception Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'lower right')
plt.show()
plt.savefig('Results/Xception-Embryo-Accuracy-Comparison.png')

# %%
# Summarize History for Loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Day 5 Embryos Xception Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc = 'lower right')
plt.show()
plt.savefig('Xception-Embryo-Loss-Comparison.png')

# %%
# Summarize History for Loss

plt.plot(history.history['val_loss'])
plt.title('Day 5 Embryos ResNet-50 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Validation'], loc = 'lower right')
plt.show()
plt.savefig('Xception-Embryo-Validation-Loss.png')

# %% [markdown]
# # Predicting Test Dataset

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predicting labels from X_test data
y_pred = xception_model.predict(x_test)

# Converting prediction classes from one hot encoding to list
# Argmax returns the position of the largest value
y_pred_classes = np.argmax(y_pred, axis = 1)

# Convert test labels from one hot encoding to list
y_test_classes = np.argmax(y_test, axis = 1)

# https://www.v7labs.com/blog/confusion-matrix-guide

# Create the confusion matrix
confmx = confusion_matrix(y_test_classes, y_pred_classes)
f, ax = plt.subplots(figsize = (8,8))
sns.heatmap(confmx, annot=True, fmt='.1f', xticklabels='auto', yticklabels='auto')
plt.xlabel('Predicted Embryo Labels')
plt.ylabel('True Embryo Labels')
plt.title('Xception Model - Day5 Embryos Testset Confusion Matrix')
#plt.savefig('Results/Day5-Embryos-Xception-Model-Confusion-Matrix.png')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       2 import seaborn as sns
#       4 # Predicting labels from X_test data
# ----> 5 y_pred = xception_model.predict(x_test)
#       7 # Converting prediction classes from one hot encoding to list
#       8 # Argmax returns the position of the largest value
#       9 y_pred_classes = np.argmax(y_pred, axis = 1)
#
# NameError: name 'xception_model' is not defined

# %%
# Printing the model scores:
print(classification_report(y_test_classes, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       118
#            1       0.99      0.93      0.96       103
#            2       0.98      1.00      0.99       118
#            3       0.97      1.00      0.98        92
#            4       1.00      0.98      0.99       179
#
#     accuracy                           0.98       610
#    macro avg       0.98      0.98      0.98       610
# weighted avg       0.98      0.98      0.98       610

# %%
y_train_arg=np.argmax(y_train,axis=1)
yp_train = np.argmax(xception_model.predict(x_train),axis=1)
print('Train Confusion Matrix')
print(confusion_matrix(y_train_arg, yp_train))
# Out:
# 52/52 [==============================] - 26s 509ms/step
# Train Confusion Matrix
# [[324   1   0   0   0]
#  [ 16 251   8   0   0]
#  [  1   0 313   1   0]
#  [  0   0   0 246   0]
#  [  1   0   1   9 475]]

# %%
y_val_arg=np.argmax(y_val,axis=1)
yp_val = np.argmax(xception_model.predict(x_val),axis=1)
print('Val Confusion Matrix')
print(confusion_matrix(y_val_arg, yp_val))
# Out:
# 6/6 [==============================] - 3s 455ms/step
# Val Confusion Matrix
# [[30  0  0  0  0]
#  [ 0 33  0  0  0]
#  [ 0  0 38  2  0]
#  [ 0  0  0 28  0]
#  [ 0  0  0  1 51]]

# %%
y_test_arg=np.argmax(y_test,axis=1)
yp_test = np.argmax(xception_model.predict(x_test),axis=1)
print('Confusion Matrix')
print(confusion_matrix(y_test_arg, yp_test))
# Out:
# 20/20 [==============================] - 13s 642ms/step
# Confusion Matrix
# [[116   1   1   0   0]
#  [  5  96   2   0   0]
#  [  0   0 118   0   0]
#  [  0   0   0  92   0]
#  [  0   0   0   3 176]]

# %% [markdown]
# # Model Evaluation

# %%
def evaluation_parametrics(name, y_train_arg, yp_train, y_val_arg, yp_val, y_test_arg, yp_test):
    
    print("\n-----------------------------{}-----------------------------\n".format(name))
    
    cm_train = confusion_matrix(y_train_arg, yp_train)
    t1 = ConfusionMatrixDisplay(cm_train)
    #s1 = round((cm_train[0,0]/(cm_train[0,0] + cm_train[0,1])),4)
    
    print("Classification Report for Train Data\n")
    print(classification_report(y_train_arg, yp_train)) 
    print("--------------------------------------------------------------------------")
    print("Recall on Train Data: ", round(recall_score(y_train_arg, yp_train, average='micro'),4))
    #print("Specificity on Train Data: ", s1)
    print("Accuracy on Train Data: ", round(accuracy_score(y_train_arg, yp_train),4))
    print("Precision on Train Data: ", round(precision_score(y_train_arg, yp_train, average='micro'),4))
    print("F1 Score on Train Data: ", round(f1_score(y_train_arg, yp_train, average='micro'),4))
    # print("ROC AUC Score on Train Data: ", round(roc_auc_score(y_train_arg, yp_train,average='micro'),4))
    print("--------------------------------------------------------------------------")
    
    
    cm_val = confusion_matrix(y_val_arg, yp_val)
    t2 = ConfusionMatrixDisplay(cm_val)
    #s2 = round((cm_val[0,0]/(cm_val[0,0] + cm_val[0,1])),4)
    
    print("\nClassification Report for Validation Data\n")
    print(classification_report(y_val_arg, yp_val))   
    print("--------------------------------------------------------------------------")
    print("Recall on Val Data: ", round(recall_score(y_val_arg, yp_val, average='micro'),4))
    #print("Specificity on Val Data: ", s2)
    print("Accuracy on Val Data: ", round(accuracy_score(y_val_arg, yp_val),4))
    print("Precision on Val Data: ", round(precision_score(y_val_arg, yp_val, average='micro'),4))
    print("F1 Score on Val Data: ", round(f1_score(y_val_arg, yp_val, average='micro'),4))
    print("--------------------------------------------------------------------------")


    cm_test = confusion_matrix(y_test_arg, yp_test)
    t3 = ConfusionMatrixDisplay(cm_test)
    #s3 = round((cm_test[0,0]/(cm_test[0,0] + cm_test[0,1])),4)
    
    print("\nClassification Report for Test Data\n")
    print(classification_report(y_test_arg, yp_test))   
    print("--------------------------------------------------------------------------")
    print("Recall on Test Data: ", round(recall_score(y_test_arg, yp_test, average='micro'), 4))
    #print("Specificity on Test Data: ", s3)
    print("Accuracy on Test Data: ", round(accuracy_score(y_test_arg, yp_test), 4))
    print("Precision on Test Data: ", round(precision_score(y_test_arg, yp_test, average='micro'), 4))
    print("F1 Score Test Data: ", round(f1_score(y_test_arg, yp_test, average='micro'), 4))
    print("--------------------------------------------------------------------------")
    
    t1.plot()
    t2.plot()
    t3.plot()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score, accuracy_score, precision_score, f1_score

# %%
evaluation_parametrics("Xception Neural Network", y_train_arg, yp_train, y_val_arg, yp_val, y_test_arg, yp_test)
# Out:
# -----------------------------Xception Neural Network-----------------------------
#
# Classification Report for Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       325
#            1       1.00      0.91      0.95       275
#            2       0.97      0.99      0.98       315
#            3       0.96      1.00      0.98       246
#            4       1.00      0.98      0.99       486
#
#     accuracy                           0.98      1647
#    macro avg       0.98      0.98      0.98      1647
# weighted avg       0.98      0.98      0.98      1647
#
# --------------------------------------------------------------------------
# Recall on Train Data:  0.9769
# Accuracy on Train Data:  0.9769
# Precision on Train Data:  0.9769
# F1 Score on Train Data:  0.9769
# --------------------------------------------------------------------------
#
# Classification Report for Validation Data
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        33
#            2       1.00      0.95      0.97        40
#            3       0.90      1.00      0.95        28
#            4       1.00      0.98      0.99        52
#
#     accuracy                           0.98       183
#    macro avg       0.98      0.99      0.98       183
# weighted avg       0.99      0.98      0.98       183
#
# --------------------------------------------------------------------------
# Recall on Val Data:  0.9836
# Accuracy on Val Data:  0.9836
# Precision on Val Data:  0.9836
# F1 Score on Val Data:  0.9836
# --------------------------------------------------------------------------
#
# Classification Report for Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       118
#            1       0.99      0.93      0.96       103
#            2       0.98      1.00      0.99       118
#            3       0.97      1.00      0.98        92
#            4       1.00      0.98      0.99       179
#
#     accuracy                           0.98       610
#    macro avg       0.98      0.98      0.98       610
# weighted avg       0.98      0.98      0.98       610
#
# --------------------------------------------------------------------------
# Recall on Test Data:  0.9803
# Accuracy on Test Data:  0.9803
# Precision on Test Data:  0.9803
# F1 Score Test Data:  0.9803
# --------------------------------------------------------------------------

# %% [markdown]
# # ROC-AUC Analysis

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
import sklearn.metrics as metrics
#predict proba
y_proba = xception_model.predict_on_batch(x_test)

# %%
micro_roc_auc_ovr = roc_auc_score(
    y_test,
    y_proba,
    multi_class="ovr",
    average="micro",
)
micro_roc_auc_ovr
# Out:
# 0.999604944907283

# %%
auc = metrics.roc_auc_score(y_test, y_proba)
auc
# Out:
# 0.9997477629675646

# %% [markdown]
# # Image Analysis using Grad-CAM

# %%
def plot_multiple_img(img_matrix_list, title_list, ncols, main_title = ""):
    
    fig, myaxes = plt.subplots(figsize = (15, 8), nrows = 2, ncols = ncols, squeeze = False)
    fig.suptitle(main_title, fontsize = 18)
    fig.subplots_adjust(wspace = 0.3)
    fig.subplots_adjust(hspace = 0.3)
    
    for i, (img, title) in enumerate(zip(img_matrix_list, title_list)):
        myaxes[i // ncols][i % ncols].imshow(img)
        myaxes[i // ncols][i % ncols].set_title(title, fontsize = 15)
        
    plt.savefig('Results/Xception-Day5-Embryos-Testset-Images-Heatmap-Analysis.png')
    plt.show()

# %% [markdown]
# Config- Parameters

# %%
# Grad-CAM

import keras
import matplotlib.cm as cm

model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions
imag = []

last_conv_layer_name = "block14_sepconv2_act"

# Reading 2 Covid & 2 Normal Images for Grad-Cam Analysis

img_path = ['embryo-dataset/ed4/alldata/1/20.png',
            'embryo-dataset/ed4/alldata/2/98.png',
            'embryo-dataset/ed4/alldata/3/47.png',
            'embryo-dataset/ed4/alldata/4/50.png',
            'embryo-dataset/ed4/alldata/5/127.png']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 6>()
#       3 import keras
#       4 import matplotlib.cm as cm
# ----> 6 model_builder = keras.applications.xception.Xception
#       7 img_size = (299, 299)
#       8 preprocess_input = keras.applications.xception.preprocess_input
#
# AttributeError: module 'keras' has no attribute 'applications'

# %% [markdown]
# Grad - CAM Algorithm

# %%
# To Get Image into numpy array


def get_img_array(img_path, size):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size = size) 
    array = tf.keras.preprocessing.image.img_to_array(img) 
    array = np.expand_dims(array, axis = 0)
    return array

# Top create heatmaps for the samples

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index = None):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])

    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %% [markdown]
# Heatmap

# %%
# Storing Heatmap values into list

Xception_embryo_heatmap = []

for i in img_path:
    img_array = preprocess_input(get_img_array(i, size = img_size))
    model = model_builder(weights = "imagenet")
    model.layers[-1].activation = None
    preds = model.predict(img_array)
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    Xception_embryo_heatmap.append(heatmap)
# Out:
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# WARNING:tensorflow:5 out of the last 142 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FC5D31B1C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 762ms/step
# WARNING:tensorflow:6 out of the last 143 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FC81F25090> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 819ms/step

# %% [markdown]
# Creating a Superimposed Viz

# %%
# To Display GradCAM output for the samples

def save_and_display_gradcam(img_path, heatmap, cam_path = "cam.jpg", alpha = 0.4):
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    heatmap = np.uint8(255 * heatmap)

    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)
    superimposed_img.save(cam_path)
    
    imag.append(cv2.imread(img_path))
    imag.append(cv2.imread("./cam.jpg"))


for i in range(len(img_path)):
    save_and_display_gradcam(img_path[i], Xception_embryo_heatmap[i])

# %%
def plot_multiple_img(img_matrix_list, title_list, ncols, main_title = ""):
    
    fig, myaxes = plt.subplots(figsize = (15, 8), nrows = 2, ncols = ncols, squeeze = False)
    fig.suptitle(main_title, fontsize = 18)
    fig.subplots_adjust(wspace = 0.3)
    fig.subplots_adjust(hspace = 0.3)
    
    for i, (img, title) in enumerate(zip(img_matrix_list, title_list)):
        myaxes[i // ncols][i % ncols].imshow(img)
        myaxes[i // ncols][i % ncols].set_title(title, fontsize = 15)
        
    plt.show()

# %%
titles_list = ["Degenerate-1",'Degenerate-1 Grad','Morula-2','Morula-2 Grad','EarlyBlastocyst-3','EarlyBlastocyst-3 Grad','FullyBlastocyst-4','FullyBlastocyst-4 Grad', 'HatchedBlastocyst-5','HatchedBlastocyst-5 Grad']

plot_multiple_img(imag, titles_list, ncols = 5, main_title = "Xception Day 5 Embryos Testset Images Heatmap Analysis")

# %% [markdown]
# # Conclusion

# %% [markdown]
# Done Exploratory Image Data Analysis on Day 5 Blastocysts vs Non-Blastocysts Images using various techniques.
#
# Applied ResNet-50 Convolutional Neural Network Model and got 98% Test Accuracy, 99% Test AUC, and 0.0535 Loss
#
# Prevented Overfitting by applying Data Augmentation on Train Images Dataset
#
# Applied Grad - CAM Analysis on Day 5 Embryos Test Images and found few insights.

# %% [markdown]
# # Test the Xception Model

# %%
#load model
from keras.models import load_model
loaded_xception_model=load_model("day5_embryo_xception_model.h5")

# %%
classes = [1, 2, 3, 4, 5]
IMG_SIZE = 128

def embryo_predict(imgfilepath):
    
    img_array = cv2.imread(imgfilepath)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE) )
    # Normalizing the image
    image=new_array/255.0
    prediction = loaded_xception_model.predict([image.reshape(-1, IMG_SIZE, IMG_SIZE, 3)])
    MaxPosition=np.argmax(prediction)  
    prediction_label=classes[MaxPosition]
    
    if prediction_label == 1:
        return "This Embryo is at the 'Degenerate' Embryo stage. Embryo failed to develop."
    elif prediction_label == 2:
        return "This Embryo is at the 'Morula' stage. More than 50% of the embryo has undergone compaction."
    elif prediction_label == 3:
        return "This Embryo is at the 'Early Blastocyst' stage. Balstocoele less than the volume of the embryo."
    elif prediction_label == 4:
        return "This Embryo is at the 'Full Blastocyst' stage. Blastocoele completely filling embryo."
    elif prediction_label == 5:
        return "This Embryo is at the 'Hatched Blastocyst' stage. Blastocysts completely hatched."

# %%
embryo_predict('embryo-dataset/ed4/alldata/1/0.png')
# Out:
# 1/1 [==============================] - 1s 945ms/step
# "This Embryo is at the 'Degenerate' Embryo stage. Embryo failed to develop."

# %%
embryo_predict('embryo-dataset/ed4/alldata/2/40.png')
# Out:
# 1/1 [==============================] - 0s 63ms/step
# "This Embryo is at the 'Morula' stage. More than 50% of the embryo has undergone compaction."

# %%
embryo_predict('embryo-dataset/ed4/alldata/3/126.png')
# Out:
# 1/1 [==============================] - 0s 62ms/step
# "This Embryo is at the 'Early Blastocyst' stage. Balstocoele less than the volume of the embryo."

# %%
embryo_predict('embryo-dataset/ed4/alldata/4/300.png')
# Out:
# 1/1 [==============================] - 0s 69ms/step
# "This Embryo is at the 'Full Blastocyst' stage. Blastocoele completely filling embryo."

# %%
embryo_predict('embryo-dataset/ed4/alldata/5/700.png')
# Out:
# 1/1 [==============================] - 0s 68ms/step
# "This Embryo is at the 'Hatched Blastocyst' stage. Blastocysts completely hatched."

# %% [markdown]
# # saliency map

# %%
# Saliency map
# https://github.com/experiencor/deep-viz-keras/blob/master/saliency.py
from keras.layers import Input, Conv2DTranspose
from keras.models import Model
from keras.initializers import Ones, Zeros

class SaliencyMask(object):
    def __init__(self, model, output_index=0):
        pass

    def get_mask(self, input_image):
        pass

    def get_smoothed_mask(self, input_image, stdev_spread=.2, nsamples=50):
        stdev = stdev_spread * (np.max(input_image) - np.min(input_image))

        total_gradients = np.zeros_like(input_image, dtype = np.float64)
        for i in range(nsamples):
            noise = np.random.normal(0, stdev, input_image.shape)
            x_value_plus_noise = input_image + noise

            total_gradients += self.get_mask(x_value_plus_noise)

        return total_gradients / nsamples

class GradientSaliency(SaliencyMask):

    def __init__(self, model, output_index = 0):
        # Define the function to compute the gradient
        input_tensors = [model.input]
        gradients = model.optimizer.get_gradients(model.output[0][output_index], model.input)
        self.compute_gradients = K.function(inputs = input_tensors, outputs = gradients)

    def get_mask(self, input_image):
        # Execute the function to compute the gradient
        x_value = np.expand_dims(input_image, axis=0)
        gradients = self.compute_gradients([x_value])[0][0]

        return gradients

# https://github.com/experiencor/deep-viz-keras/blob/master/visual_backprop.py
class VisualBackprop(SaliencyMask):
    def __init__(self, model, output_index = 0):
        inps = [model.input]           # input placeholder
        outs = [layer.output for layer in model.layers]    # all layer outputs
        self.forward_pass = K.function(inps, outs)         # evaluation function
        
        self.model = model

    def get_mask(self, input_image):
        x_value = np.expand_dims(input_image, axis=0)
        
        visual_bpr = None
        layer_outs = self.forward_pass([x_value, 0])

        for i in range(len(self.model.layers) - 1, -1, -1):
            if 'Conv2D' in str(type(self.model.layers[i])):
                layer = np.mean(layer_outs[i], axis = 3, keepdims = True)
                layer = layer - np.min(layer)
                layer = layer / (np.max(layer) - np.min(layer) + 1e-6)

                if visual_bpr is not None:
                    if visual_bpr.shape != layer.shape:
                        visual_bpr = self._deconv(visual_bpr)
                    visual_bpr = visual_bpr * layer
                else:
                    visual_bpr = layer

        return visual_bpr[0]
    
    def _deconv(self, feature_map):
        x = Input(shape = (None, None, 1))
        y = Conv2DTranspose(filters = 1, 
                            kernel_size = (3, 3), 
                            strides = (2, 2), 
                            padding = 'same', 
                            kernel_initializer = Ones(), 
                            bias_initializer = Zeros())(x)

        deconv_model = Model(inputs=[x], outputs=[y])

        inps = [deconv_model.input]   # input placeholder                                
        outs = [deconv_model.layers[-1].output]           # output placeholder
        deconv_func = K.function(inps, outs)              # evaluation function
        
        return deconv_func([feature_map, 0])[0]

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
y_train_label = lb.inverse_transform(y_train)

fig, ax = plt.subplots(10, 5, figsize = (12, 16))
fig.suptitle('vanilla gradient')
for i in range(n_classes):
    img = np.array(x_train[i])
    
    vanilla = GradientSaliency(model, y_train_label[i])
    mask = vanilla.get_mask(img)
    filter_mask = (mask > 0.0).reshape((28, 28))
    smooth_mask = vanilla.get_smoothed_mask(img)
    filter_smoothed_mask = (smooth_mask > 0.0).reshape((28, 28))

    ax[i, 0].imshow(img.reshape((28, 28)), cmap = 'gray')
    cax = ax[i, 1].imshow(mask.reshape((28, 28)), cmap = 'jet')
    fig.colorbar(cax, ax = ax[i, 1])
    ax[i, 2].imshow(mask.reshape((28, 28)) * filter_mask, cmap = 'gray')
    cax = ax[i, 3].imshow(mask.reshape((28, 28)), cmap = 'jet')
    fig.colorbar(cax, ax = ax[i, 3])
    ax[i, 4].imshow(smooth_mask.reshape((28, 28)) * filter_smoothed_mask, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 from sklearn import preprocessing
#       2 lb = preprocessing.LabelBinarizer()
# ----> 3 y_train_label = lb.inverse_transform(y_train)
#       5 fig, ax = plt.subplots(10, 5, figsize = (12, 16))
#       6 fig.suptitle('vanilla gradient')
#
# NameError: name 'y_train' is not defined

# %% [markdown]
# # ROC AUC curves

# %%
# Predicting labels from X_test data
y_pred = loaded_xception_model.predict(x_test)
# Out:
# 20/20 [==============================] - 10s 458ms/step

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

#y_test = np.array(y_test)

n_classes = 5


# Plot linewidth.
lw = 2

# Compute ROC curve and ROC area for each class


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    # Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
# Plot of a ROC curve for a specific class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
fig = plt.figure(figsize=(12, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'red', 'cornflowerblue', 'green', 'purple'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))


plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Analysis - MultilayerCNN Model-Day 5 Embryos')
plt.legend(loc="lower right")
sns.despine()
plt.savefig('Results/ROC-AUC-MultilayerCNN-Day5-Embryo-graph.png')
plt.show()
